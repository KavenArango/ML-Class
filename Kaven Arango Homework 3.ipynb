# %% [markdown]
# # Kaven Arango Homework 3
#     The needed imports

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression 
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt
import scipy.stats as stats
import Regretion as reg
import pandas as pd
import numpy as np
import math

# %% [markdown]
# # Open CSV
#     This is used to open the csv and return the csv file

# %%
def OpenCSV(CSV):
    return pd.read_csv('./CSV/'+CSV)

# %% [markdown]
# # Draw Graph
#     used to draw the grpah for non-Sklearn

# %%
def drawGraph(x,y, response_value_list):
    plt.scatter(x, y, color='red', marker='o', s=30)
    plt.plot(x, response_value_list, color = "g")
    plt.xlabel('Exploratory (independent) variable values') 
    plt.ylabel('Response (dependent) variable values ')
    plt.show()

# %% [markdown]
# # Printing do all reg
#     used to print the do all regretion

# %%
def PrintInfo(regdict):
    print('Mean of response (dependent) variable = ', regdict["Y Mean"])
    print('Mean of the exploratory (independent) variable = ', regdict["X Mean"])
    print('Covariance between exploratory and response variables = ', regdict["cov_xy"])
    print('Variance of exploratory (independent) variable = ', regdict["var_x"])
    print('beta_1_hat (slope of the best fit straight line) = ', regdict["Beta_1_hat"])
    print('beta_0_hat (intercept of the best fit straight line) = ', regdict["Beta_0_hat"])
    print('Response value list is ', regdict["response_value_list"])
    print('Errors or Residuals of Predicted Response value and Actual Exploratory value =', regdict["errors"])
    print('Sum of Residuals of Predicted and Actual Response Values = ', regdict["SumOfResiduals"])
    print('Sum Squared Residuals of Predicted and Actual Response Values = ', regdict["SumSquareResiduals"])
    print('Correlation between Exploratory and Response variables = ', regdict["r_xy"])
    print('R-square between Exploratory and Response variables = ', regdict["r_sq"])
    print('Goodness of fit :', regdict["r_sq"] , '% of the Response Variable values are explained by the line of best fit')

# %% [markdown]
# # Modified Do all Regretion
#     uses the new do all regression and uses the preintinfo to print everything the old do all regression did as well as using the drawgraph

# %%
def OurReg(x,y):
    doallreg = reg.do_all_regression_stuff(x, y)
    reDF = doallreg[1]
    regdict = doallreg[0]
    PrintInfo(regdict)
    drawGraph(x, y, regdict["response_value_list"])

# %% [markdown]
# # Sklearn Linear Regeretion
#     calls the Linear model for sklearn and returns it so u can run sklearnPredict if you used [['<data>']] for the x collom wont run if u dont use [['<data>']]

# %%
def SklearnLinear(x,y):
    regr = linear_model.LinearRegression()
    regr.fit(x, y)
    print('Intercept: ', regr.intercept_)
    print('Coefficients: ', regr.coef_)
    regr.score(x, y)
    return regr

# %% [markdown]
# # Sklearn Predict
#     Used to Predict where what the expect stock Price in this case

# %%
def SklearnPredict(x,y, regr):
    print ('Predicted Stock Index Price: \n', regr.predict([[x ,y]]))

# %% [markdown]
# # Graph for Sklearn
#     draws a Graph of the data opened and draws the predicted line for the Graph

# %%
def SklearnLinearGraph(x,y,regr):
    py = regr.predict(x)
    plt.scatter(x, y, color='red', marker='o', s=30)
    plt.plot(x, py, color = "g")
    plt.xlabel('Exploratory (independent) variable values') 
    plt.ylabel('Response (dependent) variable values ')
    plt.show()

# %%
openedCSV = OpenCSV('InterestRate.csv')
OurReg(openedCSV['Interest_Rate'], openedCSV['Stock_Index_Price'])
print("\n\n")

OurReg(openedCSV['Unemployment_Rate'], openedCSV['Stock_Index_Price'])
print("\n\n")    

reg = SklearnLinear(openedCSV[['Interest_Rate', 'Unemployment_Rate']], openedCSV['Stock_Index_Price'])
SklearnPredict(2.75, 5.3, reg)
print("\n\n")

openedCSV = OpenCSV('HousePrices.csv')
reg = SklearnLinear(openedCSV[['Square Footage']], openedCSV['House Price'])
SklearnLinearGraph(openedCSV[['Square Footage']], openedCSV[['House Price']], reg)
print("\n\n")    

openedCSV = OpenCSV('StudentGrades.csv')
reg = SklearnLinear(openedCSV[['Midterm']], openedCSV['Final Exam'])
SklearnLinearGraph(openedCSV[['Midterm']], openedCSV[['Final Exam']], reg)
# Out:
# Mean of response (dependent) variable =  1070.08
# Mean of the exploratory (independent) variable =  2.07
# Covariance between exploratory and response variables =  68.9285
# Variance of exploratory (independent) variable =  0.1222
# beta_1_hat (slope of the best fit straight line) =  564.063011
# beta_0_hat (intercept of the best fit straight line) =  -97.530433
# Response value list is  [1453.64, 1312.63, 1312.63, 1312.63, 1312.63, 1312.63, 1312.63, 1171.61, 1171.61, 1171.61, 1030.6, 1030.6, 1030.6, 889.58, 889.58, 889.58, 889.58, 889.58, 889.58, 889.58, 889.58, 889.58, 889.58, 889.58]
# Errors or Residuals of Predicted Response value and Actual Exploratory value = [10.36, 81.37, 44.37, -19.63, -56.63, -58.63, -78.63, 23.39, -12.61, -4.61, 99.4, 44.4, 16.4, 75.42, 53.42, 68.42, 81.42, 59.42, -5.58, -23.58, -13.58, -67.58, -185.58, -170.58]
# Sum of Residuals of Predicted and Actual Response Values =  -39.4
# Sum Squared Residuals of Predicted and Actual Response Values =  127016.8077
# Correlation between Exploratory and Response variables =  0.9357593643883059
# R-square between Exploratory and Response variables =  87.56455880404062
# Goodness of fit : 87.56455880404062 % of the Response Variable values are explained by the line of best fit
# Mean of response (dependent) variable =  1070.08
# Mean of the exploratory (independent) variable =  5.77
# Covariance between exploratory and response variables =  -64.1456
# Variance of exploratory (independent) variable =  0.1089
# beta_1_hat (slope of the best fit straight line) =  -589.03214
# beta_0_hat (intercept of the best fit straight line) =  4468.795448
# Response value list is  [1346.93, 1346.93, 1346.93, 1346.93, 1288.02, 1170.22, 1229.12, 1229.12, 1229.12, 1170.22, 1111.31, 993.51, 934.6, 993.51, 1052.41, 875.7, 816.8, 875.7, 875.7, 875.7, 993.51, 816.8, 816.8, 875.7]
# Errors or Residuals of Predicted Response value and Actual Exploratory value = [117.07, 47.07, 10.07, -53.93, -32.02, 83.78, 4.88, -34.12, -70.12, -3.22, 18.69, 81.49, 112.4, -28.51, -109.41, 82.3, 154.2, 73.3, 8.3, -9.7, -117.51, 5.2, -112.8, -156.7]
# Sum of Residuals of Predicted and Actual Response Values =  70.7
# Sum Squared Residuals of Predicted and Actual Response Values =  152698.5945
# Correlation between Exploratory and Response variables =  -0.9222268880307253
# R-square between Exploratory and Response variables =  85.05024330068359
# Goodness of fit : 85.05024330068359 % of the Response Variable values are explained by the line of best fit
# Intercept:  1798.4039776258546
# Coefficients:  [ 345.54008701 -250.14657137]
# Predicted Stock Index Price:
#  [1422.86238865]
#
#
#
# Intercept:  98.24832962138078
# Coefficients:  [0.10976774]
# Intercept:  31.738559304405705
# Coefficients:  [0.61916004]

# %% [markdown]
# # Graphs for linear and polynomial
#     uses sklearn to draw the linear and polynomial regression Graphs

# %%
def SklearnLinearAndPoly(df):
    
    df1 = pd.DataFrame({
        'date' : df['date'],
        'new_cases': df['positiveIncrease'],
        'new_Hospitalization':df['hospitalizedIncrease'],
        'new_deaths' : df['deathIncrease'],
        'state': df['state']
    })
    
    
    lin = LinearRegression() 
    # Fitting Polynomial Regression to the dataset, degree = 4
    
    
    poly = PolynomialFeatures(degree = 4) 
    print('************* New Cases Vs. New Hospitalization *****************')
    
    
    list_x1 = df1[['new_cases']]
    list_y1 = df1['new_Hospitalization']
    
    lin.fit(list_x1, list_y1)    
    X_poly = poly.fit_transform(list_x1) 
    
    
    poly.fit(X_poly, list_y1) 
    lin2 = LinearRegression()
    lin2.fit(X_poly, list_y1)
    
    
    # Visualising the Linear Regression results 
    plt.scatter(list_x1, list_y1, color = 'red') 
    plt.plot(list_x1, lin.predict(list_x1), color = 'green') 
    plt.title('Linear Regression') 
    plt.xlabel('Number of new cases') 
    plt.ylabel('Number of new Hospitalization') 
    plt.show() 
    
    
    ## Visualising the Polynomial Regression results 
    plt.scatter(list_x1, list_y1, color = 'red') 
    plt.plot(list_x1, lin2.predict(poly.fit_transform(list_x1)), color = 'green') 
    plt.title('Polynomial Regression') 
    plt.xlabel('Number of new cases') 
    plt.ylabel('Number of new Hospitalization') 
    plt.show()
    
    print('************* New Hospitalization Vs. New Death *****************')
    
    list_x1 = df1[['new_Hospitalization']]
    list_y1 = df1['new_deaths']
    
    lin.fit(list_x1, list_y1)    
    X_poly = poly.fit_transform(list_x1) 
    
    
    poly.fit(X_poly, list_y1) 
    lin2 = LinearRegression()
    lin2.fit(X_poly, list_y1)
    
    # Visualising the Linear Regression results 
    plt.scatter(list_x1, list_y1, color = 'red') 
    plt.plot(list_x1, lin.predict(list_x1), color = 'green') 
    plt.title('Linear Regression') 
    plt.xlabel('Number of new Hospitalization') 
    plt.ylabel('Number of new deaths') 
    plt.show() 
    
    
    ## Visualising the Polynomial Regression results 
    plt.scatter(list_x1, list_y1, color = 'red') 
    plt.plot(list_x1, lin2.predict(poly.fit_transform(list_x1)), color = 'green') 
    plt.title('Polynomial Regression') 
    plt.xlabel('Number of new Hospitalization') 
    plt.ylabel('Number of new deaths') 
    plt.show()

# %% [markdown]
# # Sklearn for linear and poly
#     Gets all the colloms with the matching state names and calls sklearn linear and poly

# %%
df = OpenCSV('all-states-history.csv')

print("GRAPHS FOR FL")
SklearnLinearAndPoly(df.loc[df['state'] == 'FL'])

print("GRAPHS FOR WY")
SklearnLinearAndPoly(df.loc[df['state'] == 'WY'])

print("GRAPHS FOR NH")
SklearnLinearAndPoly(df.loc[df['state'] == 'NH'])

print("GRAPHS FOR PA")
SklearnLinearAndPoly(df.loc[df['state'] == 'PA'])

print("GRAPHS FOR TX")
SklearnLinearAndPoly(df.loc[df['state'] == 'TX'])

print("GRAPHS FOR CA")
SklearnLinearAndPoly(df.loc[df['state'] == 'CA'])

print("GRAPHS FOR ME")
SklearnLinearAndPoly(df.loc[df['state'] == 'ME'])
# Out:
# GRAPHS FOR FL
# ************* New Cases Vs. New Hospitalization *****************
# ************* New Hospitalization Vs. New Death *****************
# GRAPHS FOR WY
# ************* New Cases Vs. New Hospitalization *****************
# ************* New Hospitalization Vs. New Death *****************
# GRAPHS FOR NH
# ************* New Cases Vs. New Hospitalization *****************
# ************* New Hospitalization Vs. New Death *****************
# GRAPHS FOR PA
# ************* New Cases Vs. New Hospitalization *****************
# ************* New Hospitalization Vs. New Death *****************
# GRAPHS FOR TX
# ************* New Cases Vs. New Hospitalization *****************
# ************* New Hospitalization Vs. New Death *****************
# GRAPHS FOR CA
# ************* New Cases Vs. New Hospitalization *****************
# ************* New Hospitalization Vs. New Death *****************
# GRAPHS FOR ME
# ************* New Cases Vs. New Hospitalization *****************
# ************* New Hospitalization Vs. New Death *****************
